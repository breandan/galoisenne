// %%
@file:DependsOn("org.jetbrains.kotlinx:kotlinx-coroutines-core:1.3.9")

// %%
import kotlinx.coroutines.*

// %%
val POPCOUNT = 10000

fun <A, B> Iterable<A>.pmap(f: suspend (A) -> B): List<B> = runBlocking {
    map { async { f(it) } }.awaitAll()
}

// %%
%use lets-plot
// Out:
//    <div id="R5cPjm"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://dl.bintray.com/jetbrains/lets-plot/lets-plot-1.5.2.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("R5cPjm").appendChild(div);
//            };
//            var e = document.getElementById("R5cPjm");
//            e.appendChild(script);
//        })();
//    </script>

// %%
val rand = kotlin.random.Random(1)

fun pdf(x: Double) = exp(-x * x / 2) / sqrt(2 * PI)

fun pdf(x: Double, μ: Double, σ: Double) = pdf((x - μ) / σ) / σ

tailrec fun cdf(z: Double, sum: Double = 0.0, term: Double = z, i: Int = 3): Double =
    when {
        z < -8.0 -> 0.0
        z > 8.0 -> 1.0
        sum + term == sum -> 0.5 + sum * pdf(z)
        else -> cdf(z, sum + term, term * z * z / i, i + 2)
    }

fun cdf(z: Double, μ: Double, σ: Double) = cdf((z - μ) / σ)

fun inverseCDF(y: Double, μ: Double = 0.0, σ: Double = 1.0) =
    inverseCDF(y, -8.0, 8.0, μ, σ)

val precision = 0.00000001
tailrec fun inverseCDF(
    y: Double, lo: Double, hi: Double,
    μ: Double, σ: Double,
    mid: Double = lo + (hi - lo) / 2
): Double = when {
    hi - lo < precision -> mid
    cdf(mid, μ, σ) > y -> inverseCDF(y, lo, mid, μ, σ)
    else -> inverseCDF(y, mid, hi, μ, σ)
}

// %%
fun compare(vararg samplers: (Double) -> Double) =
    compare(*samplers.map { f -> 
            (1..POPCOUNT).pmap { f(rand.nextDouble()) } 
        }.toTypedArray()
    )

fun compare(vararg samples: List<Double>) =
    lets_plot(mapOf<String, Any>(
        "x" to samples.fold(listOf<Double>()) { acc, function ->
            acc + function
        },
        "" to samples.mapIndexed { i, s -> List(s.size) { "PDF$i" } }.flatten()
    )).let {  
        it + geom_density(alpha = .3) { x = "x"; fill = "" } + ggsize(500, 250)
    }

// %% [markdown]
// Suppose we have two normal distributions.

// %%
val prA = { it: Double -> inverseCDF(it) }
val prB = { it: Double -> prA(it) * 1.4 + 3.5 }

compare(prA, prB)
// Out:
//    <div id="3qlc79"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// 'mapping':{
// },
// 'data':{
// },
// 'ggsize':{
// 'width':500,
// 'height':250
// },
// 'kind':"plot",
// 'scales':[],
// 'layers':[{
// 'stat':"density",
// 'mapping':{
// 'x':"x",
// 'fill':""
// },
// 'data':{
// '':["PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1" ...
// 'x':[-3.6572437696158886,-3.6328717108939843,-3.6084996521720796,-3.5841275934501753,-3.559755534728271,-3.5353834760063663,-3.511011417284462,-3.4866393585625577,-3.4622672998406534,-3.4378952411187487,-3.4135231823968444,-3.38915112367494,-3.3647790649530354,-3.340407006231131,-3.316034947509227,-3.2916628887873225,-3.2672908300654178,-3.2429187713435135,-3.218546712621609,-3.1941746538997045,-3.1698025951778,-3.145430536455896,-3.1210584777339916,-3.096686419012087,-3.0723143602901826,-3.047942301568278,-3.02357

// %% [markdown]
// How can we combine these distributions? One way is to simply average them.

// %%
val prC = { it: Double -> (prA(it) + prB(it)) / 2.0 }
compare(prA, prB, prC)
// Out:
//    <div id="iuHrcA"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// 'mapping':{
// },
// 'data':{
// },
// 'ggsize':{
// 'width':500,
// 'height':250
// },
// 'kind':"plot",
// 'scales':[],
// 'layers':[{
// 'stat':"density",
// 'mapping':{
// 'x':"x",
// 'fill':""
// },
// 'data':{
// '':["PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1" ...

// %% [markdown]
// Another way is to mix them somehow.

// %%
val prD = { it: Double -> 
    if(rand.nextBoolean()) prA(it) else prB(it) 
}

compare(prA, prB, prD)
// Out:
//    <div id="LNuPPo"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// 'mapping':{
// },
// 'data':{
// },
// 'ggsize':{
// 'width':500,
// 'height':250
// },
// 'kind':"plot",
// 'scales':[],
// 'layers':[{
// 'stat':"density",
// 'mapping':{
// 'x':"x",
// 'fill':""
// },
// 'data':{
// '':["PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF0","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1","PDF1" ...
